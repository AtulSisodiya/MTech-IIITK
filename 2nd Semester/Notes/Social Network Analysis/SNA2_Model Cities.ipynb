# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
cities = [
    'Mumbai', 'Delhi', 'Bangalore', 'Jaipur', 'Surat', 'Lucknow', 'Indore', 'Bhopal', 'Visakhapatnam', 'Patna'
]

# %%
def create_net(city_set,costs,num_edges):
    G=nx.Graph() 
    for each in cities: 
        G.add_node(each)
    # add edges randomly
    while(G.number_of_edges()<num_edges):
     c1=random.choice(l)
     c2=random.choice(l)
     if(c1!=c2) and G.has_edge(c1,c2)==0:
        w=random.choice(cost)
        G.add_edge(c1,c2,weight=w)
    return G

# %%
nx.draw(G, with_labels=1)

# %%
cost = [250, 500, 750, 1200, 1500, 2000, 3000, 3500, 4000, 5000]

# %%
import random

# %%
G.nodes()
# Out:
# NodeView(('Mumbai', 'Delhi', 'Bangalore', 'Jaipur', 'Surat', 'Lucknow', 'Indore', 'Bhopal', 'Visakhapatnam', 'Patna'))

# %%
l='Mumbai', 'Delhi', 'Bangalore', 'Jaipur', 'Surat', 'Lucknow', 'Indore', 'Bhopal', 'Visakhapatnam', 'Patna'

# %%
c1=random.choice(l)

# %%
pos=nx.circular_layout(G)
nx.draw(G,pos,with_labels=1)

# %%
nx.draw_networkx_edge_labels(G,pos)
# Out:
# {('Mumbai',
#   'Visakhapatnam'): Text(0.654508563984854, -0.47552820932863293, "{'weight': 5000}"),
#  ('Jaipur',
#   'Lucknow'): Text(-0.6545085013999776, 0.4755282188645867, "{'weight': 1500}"),
#  ('Surat',
#   'Bhopal'): Text(-0.5590170631496574, -0.18163561976454123, "{'weight': 5000}"),
#  ('Indore',
#   'Bhopal'): Text(-0.559017003545013, -0.769420888299691, "{'weight': 4000}"),
#  ('Bhopal',
#   'Patna'): Text(0.24999993219971722, -0.7694208584973689, "{'weight': 5000}")}

# %%
nx.is_connected(G)
# Out:
# False

# %%
for u in G.nodes():
 for v in G.nodes():
    print(u,v, nx.has_path(G,u,v))
# Out:
# Mumbai Mumbai True
# Mumbai Delhi False
# Mumbai Bangalore False
# Mumbai Jaipur False
# Mumbai Surat False
# Mumbai Lucknow False
# Mumbai Indore False
# Mumbai Bhopal False
# Mumbai Visakhapatnam True
# Mumbai Patna False
# Delhi Mumbai False
# Delhi Delhi True
# Delhi Bangalore False
# Delhi Jaipur False
# Delhi Surat False
# Delhi Lucknow False
# Delhi Indore False
# Delhi Bhopal False
# Delhi Visakhapatnam False
# Delhi Patna False
# Bangalore Mumbai False
# Bangalore Delhi False
# Bangalore Bangalore True
# Bangalore Jaipur False
# Bangalore Surat False
# Bangalore Lucknow False
# Bangalore Indore False
# Bangalore Bhopal False
# Bangalore Visakhapatnam False
# Bangalore Patna False
# Jaipur Mumbai False
# Jaipur Delhi False
# Jaipur Bangalore False
# Jaipur Jaipur True
# Jaipur Surat False
# Jaipur Lucknow True
# Jaipur Indore False
# Jaipur Bhopal False
# Jaipur Visakhapatnam False
# Jaipur Patna False
# Surat Mumbai False
# Surat Delhi False
# Surat Bangalore False
# Surat Jaipur False
# Surat Surat True
# Surat Lucknow False
# Surat Indore True
# Surat Bhopal True
# Surat Visakhapatnam False
# Surat Patna True
# Lucknow Mumbai False
# Lucknow Delhi False
# Lucknow Bangalore False
# Lucknow Jaipur True
# Lucknow Surat False
# Lucknow Lucknow True
# Lucknow Indore False
# Lucknow Bhopal False
# Lucknow Visakhapatnam False
# Lucknow Patna False
# Indore Mumbai False
# Indore Delhi False
# Indore Bangalore False
# Indore Jaipur False
# Indore Surat True
# Indore Lucknow False
# Indore Indore True
# Indore Bhopal True
# Indore Visakhapatnam False
# Indore Patna True
# Bhopal Mumbai False
# Bhopal Delhi False
# Bhopal Bangalore False
# Bhopal Jaipur False
# Bhopal Surat True
# Bhopal Lucknow False
# Bhopal Indore True
# Bhopal Bhopal True
# Bhopal Visakhapatnam False
# Bhopal Patna True
# Visakhapatnam Mumbai True
# Visakhapatnam Delhi False
# Visakhapatnam Bangalore False
# Visakhapatnam Jaipur False
# Visakhapatnam Surat False
# Visakhapatnam Lucknow False
# Visakhapatnam Indore False
# Visakhapatnam Bhopal False
# Visakhapatnam Visakhapatnam True
# Visakhapatnam Patna False
# Patna Mumbai False
# Patna Delhi False
# Patna Bangalore False
# Patna Jaipur False
# Patna Surat True
# Patna Lucknow False
# Patna Indore True
# Patna Bhopal True
# Patna Visakhapatnam False
# Patna Patna True
