# %%
import networkx as nx
import random

# %%
import itertools

# %%
for i in itertools.combinations([1,2,3,4],2):
    print(i)
# Out:
# (1, 2)
# (1, 3)
# (1, 4)
# (2, 3)
# (2, 4)
# (3, 4)

# %%
def communities(G):
    nodes= G.nodes()
    n=G.number_of_nodes()
    first_community=[]
    for i in range(1, (n/2)+1):                                        # bekz (1,n-1) are same as (n-1,1)
       comb=[list(x) for x in iterools.combinations(nodes,i)]
       first_community.extend(comb)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0fd94a0ee87d> in <module>
#       1 first_community=[]
# ----> 2 for i in range(1, (n/2)+1):                                        # bekz (1,n-1) are same as (n-1,1)
#       3     comb=[list(x) for x in iterools.combinations(nodes,i)]
#       4     first_community.extend(comb)
#
# NameError: name 'n' is not defined

# %%
for i in range(len(first_community)):
    num_intra_edges1.append(G.subgraph(first_community[i]).number_of_edges())

# %%
for i in range(len(first_community)):
    num_intra_edges1.append(G.subgraph(first_community[i]).number_of_edges())
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
e=G.number_of_edges()
# Out:
# [2, 3, 4, 5, 2, 3, 4, 5, 2, 3, 4, 5]

# %%
# number of inter community edges
for i in range(len(first_community)):
num_inter_edges.appned(e-num_intra_edges1=[i]-num_intra_edges1=[i])

# %%
# Find the ratio
for i in range(len(first_community)):
    ratio.appned((float)(num_intra_edges1=[i]+num_intra_edges1=[i]))/num_inter_edges[i])

# %%
max_value=max(ratio)
max_index=ratio.index(max_value)

# %%
print(first_community[max_index],second_community[max_index])

# %%
G=nx.barbel_graph(5,0)  # means that there should ne 2 clicks of size 5 and connected with 0 nodes
communities(G)
